# %%
import os
import pytesseract
from PIL import Image

# %%
myconfig = "--psm 11"
# Path to the phone gallery or folder
folder_path = "D:\PD 2"

# Path to the separate folder for images with keywords
output_folder_path = "D:\sorted images"

# List of keywords to search for
keywords = ["good","happy", "friendship", "diwali"]

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

# Loop through all the images in the folder
for filename in os.listdir(folder_path):
    if filename.endswith(".jpg") or filename.endswith(".png") or filename.endswith(".jpeg"):
        # Open the image
        image_path = os.path.join(folder_path, filename)
        image = Image.open(image_path)

        # Extract text from the image using OCR
        text = pytesseract.image_to_string(image, config=myconfig)
        print(text)

        # Check if any of the keywords are present in the text
        if any(keyword in text.lower() for keyword in keywords):
            # Move the image to the output folder
            output_path = os.path.join(output_folder_path, filename)
            image.save(output_path)

            print(f"Image '{filename}' moved to the output folder.")
        else:
            print("no image to sort")
# Out:
# am
#
# os
#
# =
#
# Se
#
# S
#
# =
#
# 8 & B
#
# =
#
# ee
#
# MinGw
#
# Recycle Bin
#
# WhatsApp
#
# Installer
#
# es
#
# BS:
#
# A=
#
# Agoda
#
# Install
#
# e
#
# a
#
# ExpressVPN
#
# Ae
#
# ae
#
# Sa
#
# ee
#
# Py
#
# ‘Google
#
# cote
#
# S
#
# me
#
# —
#
# a
#
# aa
#
# ae
#
# Dropbox
#
# ccpp
#
# programm...
#
# Microsoft
#
# ExpressVPN
#
# Edge
#
# oe,
#
# “
#
# “
#
# ke
#
# ss
#
# ee
#
# WazirX
#
# App Player
#
# Pe
#
# Visual Studio Asphalt Nitro
#
# —_—
#
# Code
#
# a
#
# c
#
# 08:
#
# 06
#
# fe)
#
# ea
#
# = ch)
#
# ENG
#
# 1
#
# 022
#
# no image to sort
# Whi
#
# «
#
# WhatsApp
#
# @ End-to-end encrypted
#
# no image to sort
# Layers of Web 3.0
#
# 1) Edge Computing It is the practice of capturing, storing, processing and analyzing data near the
#
# client, where the data is generated, instead of in a centralized data-processing warehouse.
#
# 2) Decentralized Data Network.
#
# Decentralized data networks enable various data generators to sell or trade their data without
#
# losing ownership, risking privacy or relying on intermediaries. As in web 3.0, data is decentralized
#
# which means that users will own their data.It enables you to log in securely over the Internet.
#
# without getting tracked by using internet identity.
#
# 3) Artificial Intelligence & Machine Learning
#
# Al will help in decoding and filtering online data and offering the most relevant choices to users..AS
#
# aresult, to deliver accurate data, the Internet needs Al to learn how to discriminate between the
#
# genuine and the fraudulent.
#
# 4) Blockchain
#
# no image to sort
# 2 days ago
#
# 7min
#
# WHAT IS WEB 3.0
#
# NG]
#
# SS
#
# Web 3.0 is the upcoming third generation of the internet where
#
# Se
#
# y
#
# websites and apps will be able to process information in a
#
# smart...
#
# WEB
#
# 30 WW
#
# 9 views
#
# 0 comments
#
# ee
#
# 77 ee ee ee
#
# -
#
# ao freee
#
# 2min
#
# nv)
#
# pat
#
# Sef
#
# 2 days ago
#
# yee
#
# —-
#
# WHAT IS CRYPTO MINING
#
# \
#
# CRYPTO MINING Crypto mining is a competitive process that
#
# Cb
#
# verifies and adds new transactions to the blockchain for a
#
# =
#
# cryptocurrency that...
#
# O
#
# >
#
# no image to sort
# Home
#
# COIN INFORMATION
#
# News and Updates
#
# Blog
#
# s=- COIN SOLUTION
#
# BREAKING NEWS
#
# Follow what's happening with real-time updates from around the world.
#
# =a
#
# EL SALVADOR SUCCESS STORY
#
# THE COUNTRY IS RUNNING ON BITCOIN-BITCOIN
#
# EL SALVADOR SUCCESS STORY
#
# in 2021, El Salvador was the first country in the world to make Bitcoin its national
#
# currency. The country in Central America took a step that triggered a lot of
#
# enthusiasm in the crypto community. However, the country also had to accept a lot
#
# no image to sort
# Welcome to
#
# Crypto
#
# We're on a mission to educate the masses on
#
# the transformative potential of cryptocurrency
#
# and blockchain technology. This guide is here to
#
# gently introduce you to some of the key
#
# concepts you need to kick-start your journey
#
# into the world of blockchain tech.
#
# Without further ado, let's dive down the rabbit
#
# hole.
#
# A
#
# no image to sort
# am
#
# os
#
# =
#
# Se
#
# S
#
# =
#
# 8 & B
#
# =
#
# ee
#
# MinGw
#
# Recycle Bin
#
# WhatsApp
#
# Installer
#
# es
#
# BS:
#
# A=
#
# Agoda
#
# Install
#
# e
#
# a
#
# ExpressVPN
#
# Ae
#
# ae
#
# Sa
#
# ee
#
# Py
#
# ‘Google
#
# cote
#
# S
#
# me
#
# —
#
# a
#
# aa
#
# ae
#
# Dropbox
#
# ccpp
#
# programm...
#
# Microsoft
#
# ExpressVPN
#
# Edge
#
# oe,
#
# “
#
# “
#
# ke
#
# ss
#
# ee
#
# WazirX
#
# App Player
#
# Pe
#
# Visual Studio Asphalt Nitro
#
# —_—
#
# Code
#
# a
#
# c
#
# 08:
#
# 06
#
# fe)
#
# ea
#
# = ch)
#
# ENG
#
# 1
#
# 022
#
# no image to sort
# am
#
# os
#
# =
#
# Se
#
# S
#
# =
#
# 8 & B
#
# =
#
# ee
#
# MinGw
#
# Recycle Bin
#
# WhatsApp
#
# Installer
#
# es
#
# BS:
#
# A=
#
# Agoda
#
# Install
#
# e
#
# a
#
# ExpressVPN
#
# Ae
#
# ae
#
# Sa
#
# ee
#
# Py
#
# ‘Google
#
# cote
#
# S
#
# me
#
# —
#
# a
#
# aa
#
# ae
#
# Dropbox
#
# ccpp
#
# programm...
#
# Microsoft
#
# ExpressVPN
#
# Edge
#
# oe,
#
# “
#
# “
#
# ke
#
# ss
#
# ee
#
# WazirX
#
# App Player
#
# Pe
#
# Visual Studio Asphalt Nitro
#
# —_—
#
# Code
#
# a
#
# c
#
# 08:
#
# 06
#
# fe)
#
# ea
#
# = ch)
#
# ENG
#
# 1
#
# 022
#
# no image to sort
# are RTE
#
# g
#
# GOVERNMENT OF INDIA
#
# Soc QOS
#
# Name XXXX
#
# DOB: XX-XX-XXXX
#
# RAO
#
# Gender: MALE
#
# 0000 1111 2222 He
#
# BTtrre - rat Street ar arftrare
#
# no image to sort
# aM
#
# WUT Lge
#
# 7]
#
# ~
#
# 29,
#
# 29.
#
# x os
#
# Ts
#
# HAPPY
#
# Ese eae
#
# NW
#
# sa,
#
# ais
#
# ant
#
# DIWALL
#
# *
#
# we
#
# Image 'istockphoto-1339303464-612x612.jpg' moved to the output folder.
# HAPPY
#
# FRIENDSHIP DAY
#
# IY
#
# Image 'pngtree-happy-friendship-day-picture-image_1388687.jpg' moved to the output folder.
# FARA UR
#
# grarax fant
#
# INCOME TAX DEPARTMENT
#
# g
#
# GOVT. oe NS
#
# D MANIKANDAN
#
# DURAISAMY
#
# 16/07/1986
#
# PZ:
#
# Permanent Account Number
#
# BNZPM2501F
#
# Y craniaans oben
#
# =
#
# Lou
#
# Signature
#
# ¥
#
# no image to sort
# i}
#
# pw)
#
# oh
#
# Ca)
#
# no image to sort
# wD acy @
#
# Rl
#
# ENDSEIP”
#
# &.2* DAY 2
#
# no image to sort
# @ skiff - Pri
#
# ni
#
# ee
#
# x
#
# +
#
# a
#
# x
#
# €
#
# é@ i
#
# luk
#
# andy/StandA
#
# A
#
# v
#
# c
#
# o
#
# w
#
# *
#
# 4
#
# oOo @G
#
# Ist Crypto
#
# Social Gaming Club
#
# tv 1,000.28 (Purchase) ® 0.00
#
# ap Oo
#
# @ Home
#
# @® Sports
#
# Q@ srera051
#
# @
#
# ® Blockchain
#
# @ SecurityCenter  § Transaction Record
#
# AL Game History
#
# e
#
# LJ
#
# Refer Friend
#
# Game Result
#
# 1.29 x
#
# 1.28700000 ¥y
#
# @
#
# 22°C
#
# Q Search
#
# AeGt
#
# aw
#
# eo
#
# 22:52
#
# Mostly cloudy
#
# ~PscaPMveoBvNZroGseecnm
#
# ae
#
# 16-03-2023 ©
#
# no image to sort
# What is Kanban? | Principles & Benefits of Kanban.
#
# i
#
# KANBAN
#
# To DO
#
# DOING
#
# DONE
#
# me meee ia ei i =
#
# cs a se oe Ce ee oe eo
#
# © BE
#
# 2B El
#
# ABA
#
# Ee
#
# 1
#
# BS
#
# Plan
#
# Done - Pending Final Approval
#
# Fl € 2
#
# 1
#
# Develop
#
# Done - Done
#
# 1
#
# Test
#
# “To Do - Unprioritized”
#
# “To Do - Prioritized”
#
# Launch
#
# You can design your Kanban board to reflect on each of these steps:
#
# To Do - Unprioritized > To Do - Prioritized > Plan > Develop > Test > Launch >
#
# >
#
# >I) 3:46 / 11:37 » Kanban Board >
#
# om ¢ *
#
# no image to sort
# What is Kanban? | Principles & Benefits of Kanban.
#
# i
#
# KANBAN
#
# To DO
#
# DOING
#
# DONE
#
# me meee ia ei i =
#
# cs a se oe Ce ee oe eo
#
# © BE
#
# 2B El
#
# ABA
#
# Ee
#
# 1
#
# BS
#
# Plan
#
# Done - Pending Final Approval
#
# Fl € 2
#
# 1
#
# Develop
#
# Done - Done
#
# 1
#
# Test
#
# “To Do - Unprioritized”
#
# “To Do - Prioritized”
#
# Launch
#
# You can design your Kanban board to reflect on each of these steps:
#
# To Do - Unprioritized > To Do - Prioritized > Plan > Develop > Test > Launch >
#
# >
#
# >I) 3:46 / 11:37 » Kanban Board >
#
# om ¢ *
#
# no image to sort
# What is Kanban? | Principles & Benefits of Kanban.
#
# i
#
# KANBAN
#
# To DO
#
# DOING
#
# DONE
#
# me meee ia ei i =
#
# cs a se oe Ce ee oe eo
#
# © BE
#
# 2B El
#
# ABA
#
# Ee
#
# 1
#
# BS
#
# Plan
#
# Done - Pending Final Approval
#
# Fl € 2
#
# 1
#
# Develop
#
# Done - Done
#
# 1
#
# Test
#
# “To Do - Unprioritized”
#
# “To Do - Prioritized”
#
# Launch
#
# You can design your Kanban board to reflect on each of these steps:
#
# To Do - Unprioritized > To Do - Prioritized > Plan > Develop > Test > Launch >
#
# >
#
# >I) 3:46 / 11:37 » Kanban Board >
#
# om ¢ *
#
# no image to sort
# Answer
#
# Harry Potter movies
#
# Prince (HP & half blood prince)
#
# Phoenix (HP & Order of Phoenix)
#
# Fire (HP & Goblets of Fire)
#
# Prisoner (HP & Prisoner of Azkaban)
#
# no image to sort
# a
#
# —
#
# —
#
# “Se
#
# aw
#
# >
#
# Uy
#
# |
#
# le
#
# no image to sort
# Solution found!
#
# Path:
#
# 0)]
#
# ((2, 2,
#
# 0),
#
# (3, 2,
#
# 1),
#
# (3,
#
# 0,
#
# 0),
#
# (3,
#
# 1,
#
# 1),
#
# qa,
#
# 1,
#
# 0),
#
# (2, 2,
#
# 1),
#
# (0, 2,
#
# 0),
#
# (0, 3,
#
# 1),
#
# (0,
#
# 1,
#
# 0),
#
# (0, 2,
#
# 1),
#
# (0,
#
# 0,
#
# no image to sort
# ro
#
# a
#
# 07
#
# 03
#
# ben
#
# m
#
# me
#
# Pe
#
# 06
#
# 04
#
# °°
#
# 09
#
# oa
#
# |
#
# |
#
# i)
#
# mn
#
# los
#
# 0S
#
# no image to sort
# ro
#
# a
#
# 03
#
# 07
#
# CEE GED
#
# m
#
# =I
#
# Me] 06
#
# 04
#
# Marks
#
# Bet
#
# 09
#
# oa
#
# @
#
# Hoa IE
#
# )
#
# He] 05
#
# 0s
#
# tet
#
# 08
#
# 02
#
# ‘Admission
#
# cal
#
# o
#
# Lt
#
# a
#
# no image to sort
# as
#
# Fe
#
# no image to sort

# %%
import os
import pytesseract
from PIL import Image
import shutil

# Configuration for Tesseract OCR
my_config = "--psm 11"

# Path to the phone gallery or folder
folder_path = r"D:\images for ocr model"

# Path to the separate folder for images with keywords
output_folder_path = r"D:\sorted images"

# List of keywords to search for
keywords = ["good", "happy", "friendship", "diwali"]

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

# Loop through all the images in the folder
for filename in os.listdir(folder_path):
    if filename.lower().endswith((".jpg", ".png", ".jpeg")):
        # Open the image
        image_path = os.path.join(folder_path, filename)
        try:
            image = Image.open(image_path)

            # Extract text from the image using OCR
            text = pytesseract.image_to_string(image, config=my_config)

            # Check if any of the keywords are present in the text
            if any(keyword in text.lower() for keyword in keywords):
                # Move the image to the output folder
                output_path = os.path.join(output_folder_path, filename)
                shutil.move(image_path, output_path)

                # Handle potential filename conflicts
                if os.path.exists(output_path):
                    # Append a timestamp to avoid overwriting
                    output_path = os.path.join(output_folder_path, f"{filename}_{time.time()}")

                image.save(output_path)
                
        except Exception as e:
            print(f"Error processing image '{filename}': {str(e)}")
# Out:
# Error processing image 'istockphoto-1339303464-612x612.jpg': name 'time' is not defined
# Error processing image 'pngtree-happy-friendship-day-picture-image_1388687.jpg': name 'time' is not defined
